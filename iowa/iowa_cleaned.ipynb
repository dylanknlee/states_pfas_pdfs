# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("iowa.csv")
df.drop(columns = "Unnamed: 0", inplace = True)
df
# Out:
#                                   ANALYTE     RESULTS Collection Date  \
# 0                            11CL-PF3OUDS  < 1.9 ng/L      01/31/2022
# 1                              9CL-PF3ONS  < 1.9 ng/L      01/31/2022
# 2                                   ADONA  < 1.9 ng/L      01/31/2022
# 3                                 HFPO-DA  < 1.9 ng/L      01/31/2022
# 4                        NONAFLUORO NFDHA  < 1.9 ng/L      01/31/2022
# ..                                    ...         ...             ...
# 72  PERFLUOROOCTANE SULFONIC ACID 6:2 FTS  < 1.9 ng/L      01/31/2022
# 73  PERFLUOROPENTANESULFONIC ACID (PFPES)  < 1.9 ng/L      01/31/2022
# 74        PERFLUOROPENTANOIC ACID (PFPEA)  < 1.9 ng/L      01/31/2022
# 75       PERFLUOROUNDECANOIC ACID (PFUNA)  < 1.9 ng/L      01/31/2022
# 76                    TOTAL PFOA AND PFOS  < 2.0 ng/L      01/31/2022
#
#                                         FACILITY NAME Facility ID
# 0   S/EP FRM WELLS #1 & #2 AFTER TRT (FINISHED DRI...          02
# 1   S/EP FRM WELLS #1 & #2 AFTER TRT (FINISHED DRI...          02
# 2   S/EP FRM WELLS #1 & #2 AFTER TRT (FINISHED DRI...          02
# 3   S/EP FRM WELLS #1 & #2 AFTER TRT (FINISHED DRI...          02
# 4   S/EP FRM WELLS #1 & #2 AFTER TRT (FINISHED DRI...          02
# ..                                                ...         ...
# 72                        WELL # 2 (1996) (RAW WATER)        WL02
# 73                        WELL # 2 (1996) (RAW WATER)        WL02
# 74                        WELL # 2 (1996) (RAW WATER)        WL02
# 75                        WELL # 2 (1996) (RAW WATER)        WL02
# 76                        WELL # 2 (1996) (RAW WATER)        WL02
#
# [77 rows x 5 columns]

# %% [markdown]
# - pwsid = IA5225315
# - location = IOWA CITY, JOHNSON COUNTY
# - source type = groundwater
# - population = 1300
