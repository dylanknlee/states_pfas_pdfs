# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("wyoming.csv")

# %%
analyte_data = data[data.columns[1:]]

melted_analytes = pd.melt(analyte_data, id_vars = ['TT or TH Sample ID', 'Date  Sampled'],
                          var_name = ["analyte"], value_name = "concentration")

melted_analytes["concentration"] = melted_analytes["concentration"].replace("ND", 0.0)

melted_analytes["concentration"] = [float(x.replace(" J", "")) if isinstance(x, str) else float(x) 
                                    for x in list(melted_analytes["concentration"])]

melted_analytes["analyte"] = (melted_analytes["analyte"].str.replace(", ng/L", "")
                              .str.replace("Total ", "").str.replace(",  ng/L", "")
                             )

melted_analytes["sampling_date"] = pd.to_datetime(melted_analytes['Date  Sampled'], format='%b-%y')
melted_analytes.drop(columns = ["Date  Sampled"], inplace = True)

num_rows = melted_analytes.shape[0]

melted_analytes["units"] = ["ng/L"]*num_rows
melted_analytes["is_detected"] = melted_analytes["concentration"].apply(lambda x: x > 0.0)
melted_analytes["source_type"] = ["groundwater"] * num_rows
melted_analytes["state"] = ["Wyoming"]*num_rows
melted_analytes["sampling_location"] = ["Jackson Hole Airport"]*num_rows
melted_analytes["latitude"] = [43.6088]*num_rows
melted_analytes["longitude"] = [110.7376]*num_rows
melted_analytes["data_source"] = ["Jackson Hole Airport"]*num_rows

melted_analytes.rename(columns = {'TT or TH Sample ID': "sample_id"}, inplace = True)
melted_analytes
# Out:
#     sample_id       analyte  concentration sampling_date units  is_detected  \
# 0      JW0121          PFOA            1.1    2020-06-01  ng/L         True
# 1      JW0122          PFOA            1.5    2020-06-01  ng/L         True
# 2      JW0127          PFOA            0.0    2020-06-01  ng/L        False
# 3      JW0128          PFOA            0.0    2020-06-01  ng/L        False
# 4      JW0129          PFOA            0.0    2020-06-01  ng/L        False
# ..        ...           ...            ...           ...   ...          ...
# 550      WW-7  PFOA +  PFOS            0.0    2020-08-01  ng/L        False
# 551      WW-8  PFOA +  PFOS           47.0    2020-08-01  ng/L         True
# 552      WW-9  PFOA +  PFOS           32.0    2020-08-01  ng/L         True
# 553      WW-9  PFOA +  PFOS           25.0    2021-08-01  ng/L         True
# 554      WW-9  PFOA +  PFOS           15.0    2022-05-01  ng/L         True
#
#      source_type    state     sampling_location  latitude  longitude  \
# 0    groundwater  Wyoming  Jackson Hole Airport   43.6088   110.7376
# 1    groundwater  Wyoming  Jackson Hole Airport   43.6088   110.7376
# 2    groundwater  Wyoming  Jackson Hole Airport   43.6088   110.7376
# 3    groundwater  Wyoming  Jackson Hole Airport   43.6088   110.7376
# 4    groundwater  Wyoming  Jackson Hole Airport   43.6088   110.7376
# ..           ...      ...                   ...       ...        ...
# 550  groundwater  Wyoming  Jackson Hole Airport   43.6088   110.7376
# 551  groundwater  Wyoming  Jackson Hole Airport   43.6088   110.7376
# 552  groundwater  Wyoming  Jackson Hole Airport   43.6088   110.7376
# 553  groundwater  Wyoming  Jackson Hole Airport   43.6088   110.7376
# 554  groundwater  Wyoming  Jackson Hole Airport   43.6088   110.7376
#
#               data_source
# 0    Jackson Hole Airport
# 1    Jackson Hole Airport
# 2    Jackson Hole Airport
# 3    Jackson Hole Airport
# 4    Jackson Hole Airport
# ..                    ...
# 550  Jackson Hole Airport
# 551  Jackson Hole Airport
# 552  Jackson Hole Airport
# 553  Jackson Hole Airport
# 554  Jackson Hole Airport
#
# [555 rows x 12 columns]

# %%
melted_analytes.to_csv("wyoming_cleaned.csv")
