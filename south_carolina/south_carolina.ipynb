# %%
import pandas as pd
# import tabula
import numpy as np

# %%
# tabula.convert_into("T11.pdf", "raw_data.csv", output_format="csv", pages='all')

# %%
raw_data = pd.read_csv("raw_data.csv")

# drop the 3rd column - only filled with NaN's
raw_data = raw_data.drop(raw_data.columns[2], axis = 1)

# add column names
col_names = ["System Number", "System Name", "Well Name", "Sampling Date", "Sample Labratory Control Number",
             "Field Blank Collected", "Field Blank Results in nanograms per liter (ng/L) by USEPA Method 537.1"]
raw_data.columns = col_names

# remove the first 6 rows
raw_data = raw_data.iloc[6:].reset_index(drop = True)

# fixing the system number column
raw_data = raw_data.drop(index = [6, 47, 51]).reset_index(drop = True)

system_number = np.array(["SC0220006"]*12 + ["SC0720003"]*13 + ["SC2110001"]*9 + ["SC3410001"]*9 + 
                         ["SC2210001"] + ["SC2620004"]*4 + ["SC2620009"]*2)

raw_data["System Number"] = pd.Series(system_number)

# fixing the system name column
raw_data = raw_data.drop(index = [38]).reset_index(drop = True)

system_name = np.array(["Breezy Hill Water"]*12 + ["Beaufort Jasper Water & Sewer Authority"]*13 
                       + ["City of Florence"]*9 + ["City of Bennetsville"]*8 + 
                       ["City of Georgetown"] + ["Grand Strand Water and Sewer Authority"]*6)

raw_data["System Name"] = system_name

# fixing the well name column
raw_data = raw_data.drop(index = [17, 20, 23]).reset_index(drop = True)

well_name = raw_data["Well Name"].to_list()

well_name[16:22] = ["Road 34 Near Forest (CELV)"]*2 + ["Hardeeville Well 3"]*2 + ["Highway 170 Shady Oaks"]*2

raw_data["Well Name"] = well_name

# fixing the field blank collected column
raw_data = raw_data.replace({'Field Blank Collected' : { '--' : np.nan, '√' : "Yes"}})

# fixing the final column
raw_data = raw_data.replace({'Field Blank Results in nanograms per liter (ng/L) by USEPA Method 537.1' 
                             : { '--' : np.nan}})

# one last look at the final cleaned dataset
cleaned_data = raw_data
cleaned_data
# Out:
#    System Number                              System Name  \
# 0      SC0220006                        Breezy Hill Water
# 1      SC0220006                        Breezy Hill Water
# 2      SC0220006                        Breezy Hill Water
# 3      SC0220006                        Breezy Hill Water
# 4      SC0220006                        Breezy Hill Water
# 5      SC0220006                        Breezy Hill Water
# 6      SC0220006                        Breezy Hill Water
# 7      SC0220006                        Breezy Hill Water
# 8      SC0220006                        Breezy Hill Water
# 9      SC0220006                        Breezy Hill Water
# 10     SC0220006                        Breezy Hill Water
# 11     SC0220006                        Breezy Hill Water
# 12     SC0720003  Beaufort Jasper Water & Sewer Authority
# 13     SC0720003  Beaufort Jasper Water & Sewer Authority
# 14     SC0720003  Beaufort Jasper Water & Sewer Authority
# 15     SC0720003  Beaufort Jasper Water & Sewer Authority
# 16     SC0720003  Beaufort Jasper Water & Sewer Authority
# 17     SC0720003  Beaufort Jasper Water & Sewer Authority
# 18     SC0720003  Beaufort Jasper Water & Sewer Authority
# 19     SC0720003  Beaufort Jasper Water & Sewer Authority
# 20     SC0720003  Beaufort Jasper Water & Sewer Authority
# 21     SC0720003  Beaufort Jasper Water & Sewer Authority
# 22     SC2110001                         City of Florence
# 23     SC2110001                         City of Florence
# 24     SC2110001                         City of Florence
# 25     SC2110001                         City of Florence
# 26     SC2110001                         City of Florence
# 27     SC2110001                         City of Florence
# 28     SC2110001                         City of Florence
# 29     SC2110001                         City of Florence
# 30     SC2110001                         City of Florence
# 31     SC3410001                     City of Bennetsville
# 32     SC3410001                     City of Bennetsville
# 33     SC3410001                     City of Bennetsville
# 34     SC3410001                     City of Bennetsville
# 35     SC3410001                     City of Bennetsville
# 36     SC3410001                     City of Bennetsville
# 37     SC3410001                     City of Bennetsville
# 38     SC3410001                     City of Bennetsville
# 39     SC2210001                       City of Georgetown
# 40     SC2620004   Grand Strand Water and Sewer Authority
# 41     SC2620004   Grand Strand Water and Sewer Authority
# 42     SC2620004   Grand Strand Water and Sewer Authority
# 43     SC2620004   Grand Strand Water and Sewer Authority
# 44     SC2620009   Grand Strand Water and Sewer Authority
# 45     SC2620009   Grand Strand Water and Sewer Authority
#
#                            Well Name Sampling Date  \
# 0              Well 5 Midland Valley      1-Dec-20
# 1                 Well 3 Hill Street      1-Dec-20
# 2           Well 9 Hayes Drive No. 2      1-Dec-20
# 3              Well 6 New Woodbridge      1-Dec-20
# 4                  Well 7 Greenfield      1-Dec-20
# 5             Well 13 Bettis Academy      1-Dec-20
# 6     Well 12 Sage Mill -- Tank Site      1-Dec-20
# 7                     Well 11 Edisto      1-Dec-20
# 8                Well10 Ascauga Lake      1-Dec-20
# 9                 Well 8 Hayes Drive      1-Dec-20
# 10                     Well 1 Office      1-Dec-20
# 11          Chaulk Bed Rd (New Well)      1-Dec-20
# 12        Rose Hill Well 1 Blufton 4     27-Aug-20
# 13                  Rose Hill Well 3     27-Aug-20
# 14                   SCAD Equestrian     20-Aug-20
# 15                   Bluffton Well 3     27-Aug-20
# 16        Road 34 Near Forest (CELV)     20-Aug-20
# 17        Road 34 Near Forest (CELV)     19-Nov-20
# 18                Hardeeville Well 3     20-Aug-20
# 19                Hardeeville Well 3     19-Nov-20
# 20            Highway 170 Shady Oaks     20-Aug-20
# 21            Highway 170 Shady Oaks     19-Nov-20
# 22           Well 35 Roberta Terrace     30-Jul-30
# 23              Well 34 Red Bud Lane     30-Jul-20
# 24            Well 28 Santiago Drive     30-Jul-20
# 25  Well Highway 403 -- Timmonsville     30-Jul-20
# 26               Well 18 Irby Street     30-Jul-20
# 27              Well 17 Dexter Drive     30-Jul-20
# 28         Well 21 Darlington Street     30-Jul-20
# 29    Well 45 Alligator Road -- Deep     30-Jul-20
# 30            Alligator Shallow Well     30-Jul-20
# 31                         Odom Road     20-Oct-20
# 32                         Coxe Road     20-Oct-20
# 33              Old Beauty Spot Road     20-Oct-20
# 34                       Gibson Road     20-Oct-20
# 35           Sandy Grove Church Road     20-Oct-20
# 36              New Beauty Spot Road     20-Oct-20
# 37            Old Beauty Spot Well 2     20-Oct-20
# 38             Gibson Highway Well 2     20-Oct-20
# 39                Well 1.Maryville 2     30-Sep-20
# 40                  Tern Hall No. 25     30-Sep-20
# 41                   Perry Road Well     30-Sep-20
# 42                   Long Bay No. 14     30-Sep-20
# 43                   Bay Road No. 21     30-Sep-20
# 44        Wastewater Treatment Plant     30-Sep-20
# 45        Myrtle Beach Blend Well 91     30-Sep-20
#
#    Sample Labratory Control Number Field Blank Collected  \
# 0                       20L0201-01                   NaN
# 1                       20L0195-01                   Yes
# 2                       20L0192-01                   NaN
# 3                       20L0188-01                   NaN
# 4                       20L0196-01                   NaN
# 5                       20L0204-01                   NaN
# 6                       20L0187-01                   NaN
# 7                       20L0189-01                   NaN
# 8                       20L0199-01                   NaN
# 9                       20L0203-01                   NaN
# 10                      20L0194-01                   NaN
# 11                      20L0207-01                   NaN
# 12                      20I0043-01                   Yes
# 13                      20I0041-01                   NaN
# 14                      20H1111-01                   NaN
# 15                      20I0040-01                   NaN
# 16                      20H1112-01                   Yes
# 17                      20K1055-01                   NaN
# 18                      20H1115-01                   Yes
# 19                      20K1064-01                   NaN
# 20                      20H1114-01                   NaN
# 21                      20K1054-01                   NaN
# 22                      20G1586-02                   Yes
# 23                      20G1589-02                   Yes
# 24                      20G1591-02                   Yes
# 25                      20G1592-01                   Yes
# 26                      20G1594-02                   Yes
# 27                      20G1596-02                   Yes
# 28                      20G1597-01                   Yes
# 29                      20G1599-02                   Yes
# 30                      20G1604-01                   Yes
# 31                         20J1054                   Yes
# 32                         20J1083                   Yes
# 33                         20J1061                   Yes
# 34                         20J1058                   Yes
# 35                         20J1055                   Yes
# 36                         20J1060                   Yes
# 37                 20J1056/20J1062                   Yes
# 38                         20J1059                   Yes
# 39                      20J0037-01                   Yes
# 40                      20J0030-01                   NaN
# 41                      20J0032-01                   NaN
# 42                      20J0023-01                   NaN
# 43                      20J0036-01                   NaN
# 44                      20J0020-01                   NaN
# 45                      20J0034-01                   NaN
#
#    Field Blank Results in nanograms per liter (ng/L) by USEPA Method 537.1
# 0                                                 NaN
# 1                               all 18 analytes  <2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                              all 18 analytes  <2.0
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                              all 18 analytes  <2.0
# 17                                                NaN
# 18                              all 18 analytes  <2.0
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                              all 18 analytes  <2.0
# 23                              all 18 analytes  <2.0
# 24                              all 18 analytes  <2.0
# 25                              all 18 analytes  <2.0
# 26                              all 18 analytes  <2.0
# 27                              all 18 analytes  <2.0
# 28                              all 18 analytes  <2.0
# 29                              all 18 analytes  <2.0
# 30                              all 18 analytes  <2.0
# 31                              all 18 analytes  <2.0
# 32                              all 18 analytes  <2.0
# 33                              all 18 analytes  <2.0
# 34                              all 18 analytes  <2.0
# 35                              all 18 analytes  <2.0
# 36                              all 18 analytes  <2.0
# 37                              all 18 analytes  <2.0
# 38                              all 18 analytes  <2.0
# 39                               all 18 analytes <2.0
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN

# %%
cleaned_data.to_csv("south_carolina.csv")
