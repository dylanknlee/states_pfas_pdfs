# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("south_carolina1.csv")

# Get the name of the last column
last_column = df.columns[-1]
first_column = df.columns[0]

# Drop the last column
df = df.drop(last_column, axis=1)
df = df.drop(first_column, axis = 1)

analytes = df.columns[4:]
non_analytes = df.columns[:4]

df = pd.melt(df, id_vars=non_analytes, value_vars=analytes, 
                    var_name='analyte', value_name='concentration')
df
# Out:
#     System Number                                     Name  \
# 0       SC0220006               Breezy Hill Water District
# 1       SC0220006               Breezy Hill Water District
# 2       SC0220006               Breezy Hill Water District
# 3       SC0220006               Breezy Hill Water District
# 4       SC0220006               Breezy Hill Water District
# ..            ...                                      ...
# 715     SC2620004  Grand Strand Water and  Sewer Authority
# 716     SC2620004  Grand Strand Water and  Sewer Authority
# 717     SC2620004  Grand Strand Water and  Sewer Authority
# 718     SC2620009  Grand Strand Water and  Sewer Authority
# 719     SC2620009  Grand Strand Water and  Sewer Authority
#
#                       Well Name Sampling Date analyte concentration
# 0         Well 5 Midland Valley      1-Dec-20    PFBS           *a.
# 1            Well 3 Hill Street      1-Dec-20    PFBS           4.3
# ...

# %% [markdown]
# - encode well name with the sampling location?
# - pwsid = system number? if not, can we obtain pwsid? - ask xiaojun
# - any other ways to find the location for coordinates?
# - all of this data come from groundwater wells
